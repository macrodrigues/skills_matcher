# %% [markdown]
# ## Import the CSV (pre-cleaned)

# %%
import numpy as np
import pandas as pd

# %%
jobs = pd.read_csv('jobs_scraped.csv')

# %%
jobs = jobs.set_index(['major_ISCO', 'major_jobs']).drop(['Unnamed: 0'], axis = 1).reset_index()

# %% [markdown]
# ## Filter Data Frame by careers

# %%
from ast import literal_eval
jobs['careers_in_major'] = jobs['careers_in_major'].apply(literal_eval)
jobs = jobs.explode('careers_in_major')

# %%
jobs = jobs.drop(['sub_major_ISCO','unit_group_ISCO'], axis = 1)
jobs = jobs.rename({'major_ISCO': 'ISCO'}, axis = 1)
jobs = jobs[['careers_in_major', 'ISCO', 'major_jobs', 'openings']].reset_index().drop(['index'], axis = 1)

# %%
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 43].index), axis = 0) # drop 43 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 81].index), axis = 0) # drop 81 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 94].index), axis = 0) # drop 94 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 44].index), axis = 0) # drop 44 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 41].index), axis = 0) # drop 41 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 82].index), axis = 0) # drop 82 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 96].index), axis = 0) # drop 96 careers
jobs = jobs.drop(labels = list(jobs.loc[jobs.ISCO == 73].index), axis = 0) # drop 73 careers

# %%
jobs
# Out:
#                                        careers_in_major  ISCO  \
# 0                                       Currency broker    33
# 1                                       Exchange broker    33
# 2                                  Institutional broker    33
# 3                                          Money broker    33
# 4                                        Options broker    33
# ...                                                 ...   ...
# 2153                               Radio officer (ship)    35
# 2154                                     Radio operator    35
# 2155                                 Radio telegraphist    35
# 2156                        Telecommunications engineer    35
# 2157  Verification engineer (electronics and telecom...    35
#
#                                              major_jobs   openings
# 0     BUSINESS AND ADMINISTRATION ASSOCIATE PROFESSI...  31512.208
# 1     BUSINESS AND ADMINISTRATION ASSOCIATE PROFESSI...  31512.208
# ...

# %% [markdown]
# ## Select most important careers (Feature Engineering)

# %%
filter_careers_31 = list(jobs.loc[jobs.ISCO == 31].careers_in_major.values)

# %%
items_to_remove_31 = ['Geology assistant',
                     'Hydrology assistant',
                     'Laboratory assistant (chemistry)',
                     'Laboratory assistant (physics)',
                     'Meteorology assistant',
                     'Physiology laboratory assistant',
                     'Research laboratory assistant (chemistry)',
                     'Research laboratory assistant (physics)',
                     "Surveyor's assistant",
                     'Laboratory assistant (chem.lab.)',
                     'Laboratory assistant (life science technicians)',
                     'Laboratory assistant (microbiology)',
                     'Laboratory assistant (phys.lab.)',
                     'Maintenance engineer (construction)',
                     'Maintenance technician (construction)',
                     'Fire protection engineer',
                     'Fire safety inspector (building and fire inspectors)',
                     'Ground works engineer',
                     'Air terminal inspector',
                     'Assembly engineer (construction)',
                     'Assembly supervisor (construction)',
                     'Bridge engineer',
                     'Building consultant',
                     'Building designer',
                     'Building engineer',
                     'Building inspector',
                     'Building surveyor',
                     'Control technician (construction)',
                     'Operations engineer (construction)',
                     'Operations technician (construction)',
                     'Performance improvement engineer (construction)',
                     'Performance  improvement technician (construction)',
                     'Planning engineer (construction)',
                     'Planning technician (construction)',
                     'Production engineer (construction)',
                     'Quality engineer (construction)',
                     'Supervisor (construction)',
                     'Verification engineer (construction)',
                     'Warranty engineer (construction)',
                     'Site manager (construction)',
                     'Certified forester',
                     'Parks manager (agronomy and forestry technicians)',
                     'Process operator (petroleum)',
                     'Master engineer',
                     'Master engineer',
                     'Master engineer',
                     'Master engineer',
                     'Operations technician (heat production plant)',
                     'Operations technician (incineration plant)',
                     'Operators (water works)',
                     'Master engineer',
                     'Spirits distiller (chemistry)',
                     'Supervisor (chemical engineering)',
                     'Oil distiller',
                     'Oil refiner',
                     'Supervisor (manufacture of mechanical engineering products)',
                     'Technical officer',
                     'Vehicle engineer (safety and quality inspectors)',
                     'Rock drilling foreman',
                     'Food supervisor',
                     'Mouldings repair paster',
                     'Ski supervisor',
                     'Sugar boiler',
                     'Turner',
                     'Service engineer (mechanical engineering)',
                     'Service technician (mechanical engineering)',
                     'Shipping company inspector',
                     'Ship surveyor',
                     'Inspection engineer (mechanical)',
                     'Inspection technician (mechanical engineering)',
                     'Machine designer',
                     'Motor vehicle examiner',
                     'Motor vehicle inspection engineer',
                     'Motor vehicle inspector',
                     'Operations engineer (heat production plant)',
                     'Operations engineer (sewage treatment plant)',
                     'Operations engineer (water supply works)',
                     'Performance improvement engineer (mechanical engineering)',
                     'Performance improvement technician (mechanical engineering)',
                     'Assembly engineer  (mechanical engineering)',
                     'Draughtsman; mechanical engineering',
                     'Planning engineer (mechanical engineering)',
                     'Planning technician (mechanical engineering)',
                     'Production engineer (mechanical engineering)',
                     'Quality engineer (mechanical engineering)',
                     'Instrument engineer (physics)',
                     'Laboratory animal technician',
                     'Laboratory engineer (chemistry)',
                     'Laboratory engineer (physics)',
                     'Laboratory technician (chemistry)',
                     'Laboratory technician (physics)',
                     'Materials tester (physics)',
                     'Measurement engineer (physics)',
                     'Microscopist',
                     'Calculation engineer',
                     'City engineer', 
                     'Structural engineer (civil engineering technicians)',
                     'Supervisor (civil engineering)',
                     'Electrical technician; general',
                     'Electrical testing engineer',
                     'Erection engineer (electric power)',
                     'Inspection engineer (electricity)',
                     'Inspection technician (electricity)',
                     'Concrete engineer',
                     'Construction engineer',
                     'Measurement engineer',
                     'Measurement supervisor',
                     'Measurement technician',
                     'Mine surveyor',
                     'Port engineer',
                     'Railway engineer',
                     'Road engineer',
                     'Road surveyor',
                     'Road technician',
                     'Shelter inspector',
                     'Site manager',
                     'Structural designer',
                     'Tonnage surveyor',
                     'Service engineer (electric power)',
                     'Service technician (electric power)',
                     'Supervisor (manufacture of electric power products)',
                     'Supervisor (power plant)',
                     'Calculation engineer (electric power)',
                     'Operations engineer (electric power)',
                     'Performance improvement technician (electric power)',
                     'Planning engineer (electric power)',
                     'Planning technician (electric power)',
                     'Designer (electricity)',
                     'Performance improvement engineer (electricity)',
                     'Plant engineer (electricity)',
                     'Assembly engineer (electronics/telecommunications)',
                     'Draughtsman; electronics',
                     'Inspection engineer (electronics)',
                     'Inspection technician (electronics)',
                     'Performance improvement engineer (electronics)',
                     'Performance improvement technician (electronics)',
                     'Planning engineer (electronics)',
                     'Planning technician (electronics)',
                     'Production engineer (electronics)',
                     'Quality engineer (electronics)',
                     'Service engineer (electronics)',
                     'Verification engineer (electronics and telecommunications engineering technicians)',
                     'Verification engineer (electronics and telecommunications engineering technicians)',
                     'Electrical draughtsman',
                     'Electrical power technician',
                     'Installation engineer (electrical engineering technicians)',
                     'Line engineer',
                     'Network planner',
                     'Production engineer (electrical power)',
                     'Quality engineer (electrical power)',
                     'Verification engineer (electricity)',
                     'Automotive engineer (safety and quality inspectors)', 
                     ]

# %%
filter_careers_31 = [i for i in filter_careers_31 if i not in items_to_remove_31]

# %%
filter_careers_21 = list(jobs.loc[jobs.ISCO == 21].careers_in_major.values)

# %%
items_to_remove_21 = ['Environment protection engineer',
                     'Nature conservation engineer',
                     'Operations engineer (sewage treatment)',
                     'Operations engineer (water works)',
                     'Working environment engineer',
                     'Aircraft engineer (air force)',
                     'Department engineer (precision mechanics)',
                     'Development engineer (mechanical engineering)',
                     'Estimation engineer (mechanical engineering)',
                     'Graduate engineer (automotive)',
                     'Graduate engineer (heating; water; sanitation)',
                     'Graduate engineer (machining)',
                     'Graduate engineer (mechanical design)',
                     'Graduate engineer (mechanical engineering)',
                     'Graduate engineer (planning; mechanical engineering)',
                     'Graduate engineer (rationalisation; mechanical engineering)',
                     'Graduate engineer (servicing; mechanical engineering)',
                     'Graduate engineer (systems production; mechanical engineering)',
                     'Planning engineer (metallurgy)',
                     'Planning engineer (mining)',
                     'Process engineer (metallurgy)',
                     'Process engineer (mining)',
                     'Production engineer (metallurgy)',
                     'Production engineer (mining)',
                     'Process engineer (mechanical engineering)',
                     'Product developer (mechanical engineering)',
                     'Production planner (mechanical engineering)',
                     'Tool designer',
                     'Ventilation engineer (mechanical engineers)',
                     'Welding engineer',
                     'Works engineer (mechanical engineering)',
                     'Dairy engineer',
                     'Designer (chemical technology)',
                     'Development engineer (chemical technology)',
                     'Experimental engineer (chemical technology)',
                     'Graduate engineer (chemical technology)',
                     'Graduate engineer (planning; chemical technology)',
                     'Graduate engineer (processes; chemical technology)',
                     'Graduate engineer (quality control; chemical technology)',
                     'Injection moulding engineer',
                     'Production engineer (chemical technology)',
                     'Research engineer (chemistry)',
                     'Works engineer (chemical technology)',
                     'Development engineer (mining)',
                     'Quality control engineer (mining)',
                     'Research engineer (metallurgy)',
                     'Graduate engineer (mining)',
                     'Graduate engineer (production; mining/metallurgy)',
                     'Graduate engineer (quality control; metallurgy)',
                     'Graduate mining engineer',
                     'Graduate engineer (chemistry)',
                     'Graduate engineer (building control)',
                     'Graduate engineer (building production)',
                     'Graduate engineer (building quality)',
                     'Graduate engineer (building rationalisation)',
                     'Graduate engineer (calculation)',
                     'Graduate engineer (construction)',
                     'Graduate engineer (construction consultant)',
                     'Graduate engineer (guarantee engineer; construction)',
                     'Graduate engineer (plant)',
                     'Graduate engineer (port technology)',
                     'Graduate engineer (road and hydraulic construction)',
                     'Graduate engineer (road technology)',
                     'Graduate engineer (shelter inspector)',
                     'Graduate engineer (site management)',
                     'Graduate engineer (structural design)',
                     'Graduate engineer (traffic technology)',
                     'Associate professor (physics)',
                     'Radiation protection inspector',
                     'Forecast meteorologist',
                     'Government meteorologist',
                     'Military meteorologist',
                     'Staff meteorologist',
                     'Analytical chemist',
                     'Assistant professor (chemistry)',
                     'Scientist (pharmacology)',
                     'Agricultural adviser',
                     'Agricultural consultant',
                     'Agricultural graduate',
                     'Agricultural machinery consultant',
                     'Agrologist (farming adviser)',
                     'Agrologist (works manager)',
                     'Area manager; forestry',
                     'Forest technician',
                     'Fruit-growing consultant',
                     'Gamekeeper',
                     'Game manager',
                     'Game supervisor',
                     'Horticultural graduate',
                     'Horticultural graduate (gardening consultant)',
                     'Environmental statistician',
                     'Mathematical statistician',
                     'Method statistician',
                     'Population statistician',
                     'Crop consultant',
                     'Farming consultant',
                     'Forestry consultant',
                     'Horticultural consultant',
                     'Research officer (agriculture)',
                     'Research engineer (construction)',
                     'Research engineer (mechanical engineering)',
                     'State forest warden',
                     'Crown forests superintendent',
                     'Forest engineer (forestry adviser)',
                     'Forest management scientist',
                     'Forestry adviser',
                     'Forestry instructor',
                     'Actuary',
                     'Insurance actuary',
                     'Insurance mathematician',
                     'Crop protection specialist',
                     'Fisheries adviser',
                     'Professional hunter',
                     'Rural developer',
                     'Energy adviser',
                     'Environmental coordinator',
                     'Environmental inspector',
                     'Environment protection inspector',
                     'Environment protection manager',
                     'Hygienic products engineer',
                     'Inspection engineer',
                     'Material planner',
                     'Occupational hygienist',
                     'Materials control engineer (mechanical engineering)'
                     'Street maintenance engineer',
                     'Structural engineer (civil engineers)',
                     'Testing engineer (construction)',
                     'Rolling-mill engineer' 
                     ]

# %%
filter_careers_21 = [i for i in filter_careers_21 if i not in items_to_remove_21]

# %%
filter_careers_35= list(jobs.loc[jobs.ISCO == 35].careers_in_major.values)

# %%
items_to_remove_35 = ['Video engineer/service engineer',
                     'Video engineer (technical supervisor)',
                     'Video mixer',
                     'Video mixer engineer',
                     'Supervisor (data processing)',
                     'IT support engineer',
                     'Videotape engineer',
                     'Videotape technician', 
                     'Film cutter',
                     'Lighting setter',
                     'Lighting supervisor',
                     'Network designer',
                     'Network operator',
                     'Cameraman/Camerawoman (animated films)',
                     'Cameraman (TV)',
                     'Coast guard assistant (broadcasting and telecommunications equipment operators)',
                     'Microfilmer',
                     'Mixer (audio technician)',
                     'Soundtrack engineer',
                     'Stage inspector',
                     'Stage technician',
                     'Radio officer (ship)',
                     'Operations connection technician',
                     'Outside Broadcast assistant',
                     'Outside Broadcast technician',
                     'Re-recording technician',
                     'Second cameraman',
                     'Communications technician',
                     'Computer operator',
                     'Computer adviser',
                     'IT technician',
                     'Network technician', 
                     ]

# %%
filter_careers_35 = [i for i in filter_careers_35 if i not in items_to_remove_35]

# %%
filter_careers_42 = list(jobs.loc[jobs.ISCO == 42].careers_in_major.values)

# %%
items_to_remove_42 = ['Air traffic assistant',
                     'Booking assistant (travel agency)',
                     'Check-in assistant',
                     'Traffic assistant',
                     'Travel agency assistant',
                     'Surgery assistant',
                     'Porter (receptionists and information clerks)',
                     'Bank clerk',
                     'Cashier instructor',
                     'Business host/hostess',
                     'Conference host/hostess (receptionists and information clerks)',
                     'Course host/hostess',
                     'Night porter',
                     'Visits scheduler',
                     'Complaints officer',
                     'Bingo steward',
                     'Croupier',
                     'Pawnbroker',
                     'Assistant bailiff',
                     'Bailiff',
                     'Collection officer',
                     'Debt-collector',
                     'Debt recovery officer',
                     'Enforcement commissioner',
                     'Enforcement inspector',
                     'Writ server',
                     'Assistant (tourist information office)',
                     'Booking officer (travel agency)',
                     'Business travel salesperson',
                     'Charter travel salesperson',
                     'Cottage manager',
                     'Employee (tourist information office)',
                     'Ground hostess',
                     'Private travel agent',
                     'Secretary (tourist information office)',
                     'Service manager (air traffic)',
                     'Ticket seller (travel agency)',
                     'Hotel host',
                     'Hotel concierge',
                     'Office caretaker',
                     'Office receptionist', 
                     'Taxi dispatcher' 
                     ]

# %%
filter_careers_42 = [i for i in filter_careers_42 if i not in items_to_remove_42]

# %%
filter_careers_25 = list(jobs.loc[jobs.ISCO == 25].careers_in_major.values)

# %%
items_to_remove_25 = ['Graduate engineer (system development)',
                     'IT auditor',
                     'IT consultant',
                     'System analyst',
                     'System attendant',
                     'System investigator',
                     'System tester',
                     'Computer engineer (computer programmers; computer systems designers and analysts)',
                     'IT investigator',
                     'IT security manager',
                     'IT strategist',
                     'Computer methods director',
                     'Interaction designer',
                     'Programmer',
                     'Data processing coordinator',
                     'Data processing investigator',
                     'Data processing operator',
                     'Data processing strategist',
                     'IT architect',
                     'Method analyst (computing)',
                     'System manager',
                     'Access supervisor; data processing/IT',
                     'Database administrator',
                     'Web programmer',
                     'Usability designer',
                     'Application engineer (computer manufacturing)',
                     'Informatics assistant',
                     'Program developer',
                     'Security administrator (data processing/IT)',
                     'Security director (data processing/IT)',
                     'Computer security director',
                     'Computer security manager',
                     'Network administrator',
                     'System administrator',
                     'System director',
                     'System operator',
                     'Systems manager',
                     'System supervisor',
                     'System architect',
                     'Traffic inspector',
                     'Computer security director',
                     'Computer security manager', 
                     ]

# %%
filter_careers_25 = [i for i in filter_careers_25 if i not in items_to_remove_25]

# %%
filter_careers_25.extend(['Data scientist', 'Data engineer', 'Machine learning engineer', 'UI designer', 'UX designer', 'Cybersecurity', 'Blockchain developer'])

# %%
filter_careers_54 = list(jobs.loc[jobs.ISCO == 54].careers_in_major.values)

# %%
items_to_remove_54 = ['Firefighter (ambulance driver)',
                     'Fire protection planner',
                     'Fire safety inspector (fire-fighters)',
                     'Fire station deputy manager',
                     'Fire station manager',
                     'Fire technician',
                     'Senior firefighter',
                     'Police constable',
                     'Traffic policeman',
                     'Uniformed constable',
                     'Correctional facility officer',
                     'Prison warder',
                     'Security officer',
                     'Security supervisor',
                     'Bodyguard (police officers; police inspectors and detectives)',
                     'Car park attendant',
                     'Churchyard attendant',
                     'Cinema attendant',
                     'Circulating watchman',
                     'Hotel porter',
                     'Lock-keeper',
                     'Night watch attendant',
                     'Other security staff',
                     'Public baths lifeguard',
                     'Road guard',
                     'Security transport driver',
                     'Shop inspector',
                     'Swimming-pool attendant',
                     'Traffic attendant',
                     'Traffic supervisor',
                     'Traffic warden',
                     'Security officer (railway)',
                     'Shopwalker',
                     'Stationary security guard',
                     'Alarm operator',
                     'Assistant swimming pool attendant',
                     'Game warden',
                     'Garage security guard',
                     'Port warden',
                     'Beach guard',
                     'Porter (doorkeepers; watchpersons and related workers)',
                     'Protective guard',
                     'Patrolman', 
                     ]

# %%
filter_careers_54 = [i for i in filter_careers_54 if i not in items_to_remove_54]

# %%
filter_careers_12 = list(jobs.loc[jobs.ISCO == 12].careers_in_major.values)

# %%
items_to_remove_12 = ['Graduate engineer (sales)',
                      'Chief financial and operating officer',
                      'Laundry manager',
                      'Bus/coach station manager',
                      'Division manager',
                      'Office manager (educational company)',
                      'District manager (insurance)',
                      'Regional manager (sales)'
                     ]

# %%
filter_careers_12 = [i for i in filter_careers_12 if i not in items_to_remove_12]

# %%
filter_careers_53 = list(jobs.loc[jobs.ISCO == 53].careers_in_major.values)

# %%
items_to_remove_53 = ['Day-care childminder',
                     'Family nursery childminder',
                     'Peer supporter',
                     'Assistant (care of the learning disabled)',
                     'Child rehabilitation assistant',
                     "Children's and young people's attendant",
                     'Dialysis assistant',
                     'Home care assistant (institution-based personal care workers)',
                     "Educator's assistant",
                     "Pupils' assistant",
                     "Teacher's assistant",
                     'Physiotherapy assistant',
                     'Surgical assistant',
                     'Therapy assistant',
                     'Work therapy assistant',
                     'Activities of daily life assistant',
                     "Disabled person's assistant",
                     'Home care assistant (companions; valets and home-based personal care workers)',
                     'Home help assistant',
                     'Personal assistant',
                     'Relief assistant',
                     'Autopsy assistant',
                     'Laboratory assistant (personal care and related workers)',
                     'Pharmacy assistant',
                     'Home help',
                     'Group leader (care of the disabled)',
                     'Swimming pool attendant (hospital)', 
                     "Disabled person's nurse",
                     'Assistant nurse (sterilisation centre)'
                     ]

# %%
filter_careers_53 = [i for i in filter_careers_53 if i not in items_to_remove_53]

# %%
filter_careers_91 = list(jobs.loc[jobs.ISCO == 91].careers_in_major.values)

# %%
items_to_remove_91 = ['Child sitter (occasional)',
                     'Au pair',
                     'Domestic cleaner',
                     'Domestic helper',
                     'Domestic worker',
                     'Aircraft cleaner',
                     'Breakfast assistant',
                     'Breakfast host/hostess',
                     'Cleaner (helpers and cleaners in offices; hotels and other establishments)',
                     'Cleaning worker',
                     'Hospital cleaner',
                     'Hotel cleaner',
                     'House cleaner',
                     'Industry cleaner',
                     'Laboratory dishwasher',
                     'Office cleaner',
                     'Stairs cleaner',
                     'Team supervisor (cleaning)',
                     'Dry-cleaner',
                     'Furniture washer',
                     'Carpet washer',
                     'Cleaner-up',
                     'Construction site cleaner',
                     'Air terminal inspector',
                     'Air terminal inspector',
                     'Railway car cleaner', 
                      
                     ]

# %%
filter_careers_91 = [i for i in filter_careers_91 if i not in items_to_remove_91]

# %%
filter_careers_33 = list(jobs.loc[jobs.ISCO == 33].careers_in_major.values)

# %%
items_to_remove_33 = ['Options broker', 
                      'Stockbroker',                   
                      'Stock exchange agent',
                      'Stock exchange agent',
                      'Company economic adviser',
                      'Credit rating officer',
                      'Customer attendant (garage)',
                      'Department head (bank)',
                      'Group director (bank)',
                      'Print shop supervisor',
                      'Quantity surveyor (construction)',
                      'Service adviser (garage)',
                      'Service manager (garage)',
                      'Shop supervisor (garage)',
                      'Supervisor (garage)',
                      "Auditor's assistant",
                      'Checking clerk',
                      'Chief accountant (bookkeepers; statistical; mathematical and related professionals)',
                      'Claims inspector (insurance)',
                      'Customer clerk (insurance)',
                      'Damages engineer (insurance)',
                      'Damages inspector (insurance)',
                      'Damages technician',
                      'Field claims adjuster',
                      'Field officer (insurance)',
                      'Spare time insurance agent',
                      'Underwriter',
                      "Underwriter's assistant",
                      'Advertising seller (Technical and commercial sales representatives)',
                      'Agent (retail)',
                      'Agent (service company)',
                      'Canvasser',
                      'Vehicle damage inspector (insurance)',
                      'Advertising seller (Technical and commercial sales representatives)',
                      'Underwriter',
                      "Underwriter's assistant",
                      'Office manager (medical care)',
                      'Office manager (public administration)',
                      'Office manager (warehouse)',
                      'Legal secretary',
                      'Adman',
                      'Study adviser (administrative secretaries and related associate professionals)',
                      'Study assistant',
                      'Study secretary',
                      'Currency broker',
                      'Institutional broker',
                      'Securities broker',
                      'Stock exchange broker',
                      'Business adviser; shop',
                      'Credit clerk',
                      'Credit investigator',
                      'Estimating officer',
                      'Order clerk',
                      'Order distributor',
                      'Estimating clerk',
                      'Order clerk',
                      'Order distributor',
                      "Restaurant manager's assistant",
                      'Educational secretary',
                      'Trust manager (bank)',
                      'Trust officer (bank)',
                      'Boat damages inspector',
                      'Order planner',
                      'Production supervisor (printing)',
                      'Purchasing supervisor (printing)',
                      'Marine surveyor',
                      'Buying supervisor',
                      'Regrater',
                      'Employment officer',
                      'Area administrator',
                      "Broker's assistant",
                      'Insurance clerk',
                      'Commercial agent; wholesale',
                      'Export forwarder',
                      'Advertising seller (door-to-door and telephone salespersons; shop sales persons and demonstrators)',
                      "Managing director's secretary",
                      'Advertising assistant (Finance and sales professionals)',
                      'Bids clerk',
                      'Credit supervisor',
                      'Tenderer',
                      'Estimating engineer',
                      'Insurance agent',
                     'Insurance broker',
                     'Insurance consultant',
                     'Insurance expert',
                     'Insurance investigator',
                     'Insurance officer',
                     'Transport administrator',
                     'Transport adviser',
                     'Transport coordinator',
                     'Transport engineer',
                     'Transport planner', 
                     'Real estate assistant',
                     'Real estate book-keeper',
                     'Real estate broker',
                     'Real estate inspector',
                     'Real estate manager',
                     'Real estate secretary',
                     'Real estate administrator',
                     'Real estate agent',
                     'Rent adviser',
                     'Rent inspector',
                     'Rent supervisor',
                     'Ledger clerk',
                     'Statistics clerk',
                     'Customs clerk',
                     'Forwarding clerk (clearing and forwarding agents)',
                     'Chief clerk',
                     'Municipal clerk',
                     'Cost estimator',
                     'Credit adviser',
                     'Credit manager',
                     'Credit officer',
                     'Farm accountant',
                     'Machine accountant',
                     'Civil claims adjuster',
                     'Civil damages inspector',
                     'Claims adjuster',
                     'Fire claims adjuster',
                     'Estimating manager',
                     'Motor claims adjuster',
                     'Personal claims adjuster',
                     'Rate setter',
                     'Risk engineer',
                     'Risk evaluator',
                     'Purchasing planner',
                     'Purchasing technician',
                     'Wholesale agent',
                     'Airfreight agent',
                     'Customs clearance officer',
                     'Customs manifest draftsman',
                     'Customs representative',
                     'Forwarding agent',
                     'Forwarding supervisor',
                     'Import forwarder',
                     'Shipping agent (clearing and forwarding agents)',
                     'Operations manager (property)',
                     'Agent (music)',
                     'Aircraft broker',
                     "Artists' booking agent",
                     'Auction assistant',
                     "Auctioneer's assistant",
                     'Admissions secretary (education)',
                     'Association secretary (interest group society)',
                     'Continuing training secretary',
                     'Course administrator',
                     'Cultural secretary',
                     'Division secretary',
                     'Executive secretary',
                     'Institutional secretary',
                     'Management secretary',
                     'Programme secretary',
                     'Research commission secretary',
                     'Sales operations secretary',
                     'Sales secretary',
                     'School secretary',
                     'Trade secretary',
                     'Trade union secretary',
                     'Clinical secretary',
                     'Medical secretary' 
                     ]

# %%
filter_careers_33 = [i for i in filter_careers_33 if i not in items_to_remove_33]

# %%
filter_careers_23 = list(jobs.loc[jobs.ISCO == 23].careers_in_major.values)

# %%
items_to_remove_23 = ['Special pedagogue for the hearing impaired',
                      'Special pedagogue for the visually impaired',
                      'Special teacher for the hearing impaired',
                      'Special teacher for the visually impaired',
                      'Special teacher in remedial school',
                      'Home language trainer',
                      'Language teacher (immigrants)',
                      'Certified music teacher',
                      'Choir leader',
                      'Musical trainer',
                      'Music educator',
                      'Music teacher at a music school', 
                      'Pedagogue (singing)',
                      'Computer trainer',
                      'Computer instructor',
                      'Teacher (hearing impaired)',
                      'Teacher for students with a speech or language impairment',
                      'Senior secondary school teacher of languages',
                      'Senior secondary school teacher of mathematics and natural sciences',
                      'Senior secondary school teacher of technology',
                      'Subject teacher (history; social sciences)',
                      'Teacher of painting techniques',
                      'Class teacher (forms 1-3)',
                      'Class teacher (forms 1-7)',
                      'Class teacher (forms 4-7)',
                      'Compulsory school teacher (forms 1-7)',
                      'Compulsory school teacher (forms 4-9)',
                      'Compulsory school teacher (upper forms)',
                      'Freinet teacher',
                      'Language teacher (compulsory education)',
                      'Teacher in Waldorf school',
                      'Teacher specialising in work with immigrants',
                      'Director (after-school centre)',
                      'Montessori practitioner',
                      'Native language teacher (pre-primary school)',
                      'Waldorf practitioner (after-school centre)',
                      'Waldorf practitioner (preschool)',
                      'Adviser (matters of further education)',
                      'Audiological adviser',
                      'Course developer',
                      'Educational consultant',
                      'Peripatetic teacher',
                      'Preschool adviser',
                      'School adviser',
                      'Study instructor (education methods specialists; school inspectors)',
                      'Teaching aids manager',
                      'Training adviser',
                      'Remedial educator',
                      'Remedial teacher',
                      'Remedial teacher in secondary school',
                      'Specialist pedagogue in speech and language therapy',
                      'Teacher of textile science',
                      'Teacher of construction steel sheet work',
                      'Teacher of dancing and drama',
                      'Teacher of institutional catering',
                      'Teacher of operational and energy technologies',
                      'Teacher of ship technology',
                      'Teacher of sound and music',
                      'Natural resource management teacher',
                      'Needlework teacher',
                      'Plumbing; heating and ventilation instructor',
                      'Sewing teacher',
                      'Subject teacher (economics)',
                      'Teacher (adult education centre)',
                      'Teacher (baking and confectionery)',
                      'Teacher of textile and clothing technology',
                      'Teacher of textile craft and woodwork',
                      'College teacher of artistic subjects',
                      'College teacher of biology; chemistry; geology',
                      'College teacher of computer science; system science',
                      'College teacher of culture; information',
                         'College teacher of economics; administration; social science',
                         'College teacher of history; philosophical subjects',
                         'College teacher of law; social sciences',
                         'College teacher of linguistic subjects',
                         'College teacher of mathematics; physics',
                         'College teacher of medical subjects',
                         'College teacher of music',
                         'College teacher of nursing subjects',
                         'College teacher of pedagogy',
                         'College teacher of psychology; social subjects',
                         'College teacher of technological subjects',
                         'Language teacher at college level',
                         'Music teacher at college level',
                         'University teacher (art and design)',
                         'University teacher (biology; chemistry; geology)',
                         'University teacher (computer science; systems science)',
                         'University teacher (culture; information)',
                         'University teacher (economics; administration; social sciences)',
                         'University teacher (history and philosophy)',
                         'University teacher (languages and linguistics)',
                         'University teacher (law; social sciences)',
                         'University teacher (mathematics; physics)',
                         'University teacher (medicine)',
                         'University teacher (music)',
                         'University teacher (nursing)',
                         'University teacher (pedagogy)',
                         'University teacher (psychology; social subjects)',
                         'University teacher (technology)',
                         'Electrical engineering and telecommunications technology teacher',
                         'Electrical technology teacher',
                         'Drama educator',
                         'Play therapist',
                         'Senior secondary school teacher of economics',
                         'Senior secondary school teacher of history and social sciences',
                         'Power management instructor', 
                     ]

# %%
filter_careers_23= [i for i in filter_careers_23 if i not in items_to_remove_23]

# %%
filter_careers_32 = list(jobs.loc[jobs.ISCO == 32].careers_in_major.values)

# %%
items_to_remove_32 = ['Hospital engineer',
                      'Medical technical engineer',
                      'Blood centre staff',
                      'Laboratory assistant (biochemistry/medicine)',
                      'Laboratory assistant (clinical chemistry)',
                      'Laboratory assistant (clinical physiology)',
                      'Laboratory assistant (histopathology)',
                      'Laboratory assistant (hospital)',
                      'Dispenser',
                      "Dental technician's assistant",
                      'Disability aids mechanic',
                      'Plaster technician',
                      'Surgical truss maker',
                      'Clinical department administrator',
                      'Colostomy nurse',
                      'Company nurse',
                      'Diabetes nurse',
                      'Dialysis nurse',
                      'Emergency medical technician',
                      'Geriatrics nurse',
                      'Hypertension nurse',
                     'Medically responsible nurse',
                     'Medical technical assistant',
                     'Municipal nurse',
                     'Nurse (casualty; emergency room)',
                     'Nurse (childcare centre)',
                     'Nurse (diagnostic radiology)',
                     'Nurse (geriatric care)',
                     'Nurse (medicine/surgery)',
                     'Nurse (psychiatric care)',
                     'Radiology nurse',
                     'Radiotherapy assistant',
                     'Nursing assistant (nursing home)',
                     'Nursing assistant (psychiatric care)',
                     'Nursing assistant (treatment work)',
                     'Nursing attendant',
                     'Nursing auxiliary',
                     'Nursing developer',
                     'Nursing method developer',
                     'Allergy nurse',
                     'Anaesthesia nurse',
                     'Emergency nurse',
                     'Intensive care nurse (ICU)',
                     'Ophthalmology nurse',
                     'Pain relief nurse',
                     'Pediatric nurse',
                     'Pediatric nurse (nursing ward)',
                     'Pediatric nurse (surgery)',
                     'School nurse',
                     'Staff nurse',
                     'X-ray nurse',
                     'Allergy nurse',
                     'Anaesthesia nurse',
                     'Emergency nurse',
                     'Intensive care nurse (ICU)',
                     'Ophthalmology nurse',
                     'Pain relief nurse',
                     'Pediatric nurse',
                     'Pediatric nurse (nursing ward)',
                     'Pediatric nurse (surgery)',
                     'School nurse',
                     'Staff nurse',
                     'X-ray nurse',
                     'Allergy nurse',
                     'Anaesthesia nurse',
                     'Emergency nurse',
                     'Intensive care nurse (ICU)',
                     'Ophthalmology nurse',
                     'Pain relief nurse',
                     'Pediatric nurse',
                     'Pediatric nurse (nursing ward)',
                     'Pediatric nurse (surgery)',
                     'School nurse',
                     'Staff nurse',
                     'X-ray nurse',
                     'Cytology assistant',
                     'Anaesthesia assistant',
                     'Nursing assistant',
                     'Nursing assistant (care of people with learning disabilities)',
                     'Oncological assistant',
                     'Ophthalmological assistant',
                     'Anaesthesia assistant',
                     'Nursing assistant',
                     'Nursing assistant (care of people with learning disabilities)',
                     'Oncological assistant',
                     'Ophthalmological assistant',
                     'Anaesthesia assistant',
                     'Nursing assistant',
                     'Nursing assistant (care of people with learning disabilities)',
                     'Oncological assistant',
                     'Ophthalmological assistant',
                     'Animal health assistant',
                     'Veterinary assistant',
                     'Nursing administrator',
                     'Clinical department director'
                     ]

# %%
filter_careers_32= [i for i in filter_careers_32 if i not in items_to_remove_32]

# %%
filter_careers_32.extend(['Nurse'])

# %%
filter_careers_22 = list(jobs.loc[jobs.ISCO == 22].careers_in_major.values)

# %%
items_to_remove_22 = ['Medical practitioner (general practitioner)',
                     'Panel doctor',
                     'Pre-registration primary care physician',
                     'Chief school doctor',                      
                     'Internal medicine specialist',
                     'Medical examiner',
                     'Medical practitioner (child specialist)',
                     'Medical practitioner (clinical chemistry specialist)',
                     'Medical practitioner (clinical nutrition)',
                     'Medical practitioner (industrial health care)',
                     'Medical practitioner (infectious diseases)',
                     'Medical practitioner (internal medicine specialist)',
                     'Medical practitioner (nuclear medicine specialist)',
                     'Medical practitioner (operations specialist)',
                     'Medical practitioner (psychiatric specialist)',
                     'Medical practitioner (radiology specialist)',
                     'Medical practitioner (school health care)',
                     'Medical practitioner (skin and venereal diseases)',
                     'Medical practitioner (social medicine)',
                     'Medical practitioner (social medicine specialist )',
                     'Medical rehabilitation specialist',
                     'Speech therapist (medical doctors)',
                     'Charge nurse (ward/surgery)',
                     'Nurse (ambulance driver)',
                     'Nurse (surgery department)',
                     'Nursing teacher',
                     'Operating theatre nurse',
                     'Midwife',
                     'Midwife (delivery ward)',
                     'Midwife (maternity ward)',
                     'Midwife (primary care)',
                     'Graduate pharmacist (pharmacy)',
                     'Hospital pharmacist',
                     'Information pharmacist',
                     'Diet economist',  
                     'Staff welfare adviser',
                     'Staff welfare officer',
                     'Working environment inspector',
                     'Adviser (motor impaired)',
                     'Chief company doctor',
                     'Zone therapist',
                     'Animal welfare officer',
                     'City veterinary officer',
                     'Clinical veterinary surgeon', 
                      
    ]

# %%
filter_careers_22 = [i for i in filter_careers_22 if i not in items_to_remove_22]

# %%
filter_careers_61 = list(jobs.loc[jobs.ISCO == 61].careers_in_major.values)

# %%
items_to_remove_61 = ['Supervisor (crop farming)',
                     'Tenant farmer (crop farming)',
                     'Farmer (crop farming)',
                     'Farm foreman (crop farming)',
                     'Farming foreman',
                     'Supervisor (crop farming)',
                     'Tenant farmer (crop farming)',
                     'Farmer (crop farming)',
                     'Farm foreman (crop farming)',
                     'Farming foreman',
                     'Supervisor (crop farming)',
                     'Tenant farmer (crop farming)',
                     'Farmer (crop farming)',
                     'Farm foreman (crop farming)',
                     'Farming foreman',
                     'Supervisor (crop farming)',
                     'Tenant farmer (crop farming)',
                     'Berry grower',
                     'Farmer (crop farming)',
                     'Farm foreman (crop farming)',
                     'Farming foreman', 
                     'Tenant farmer (mixed production)',
                     'Farmer (mixed production)',
                     'Farm foreman (mixed production)',
                     'Farm manager (mixed production)',
                     'Farm supervisor (mixed production)',
                     'AI assistant',
                     'Farmer (animal husbandry)',
                     'Fur animal breeder',
                     'Groom', 
                     'Horse breeder',
                     'Insemination assistant',
                     'Gardener (landscaping)',
                     'Garden supervisor',
                     'Milk recorder',
                     'Mink farmer',
                     'Poultry farm owner',
                     'Poultry farm worker',
                     'Poultry keeper',
                     'Poultry worker',
                     'Flower grower',
                     'Garden manager',
                     'Greenkeeper',
                     'Landscape gardener',
                     'Landscaping supervisor',
                      
                      
                     ]

# %%
filter_careers_61 = [i for i in filter_careers_61 if i not in items_to_remove_61]

# %%
filter_careers_83 = list(jobs.loc[jobs.ISCO == 83].careers_in_major.values)

# %%
items_to_remove_83 = ['Engine-driving instructor',
                      'Industrial engine driver',
                     'Railway locomotive driver',
                     'Shuttle train driver',
                     'Tramway coach driver',
                     'Underground train driver',
                     'Depot engine driver (tunnel train)',
                     'Radio engine driver',
                     'Railway car coupler',
                     'Railway yard operator',
                     'Shunting supervisor (locomotive-engine drivers)',
                     'Shunting supervisor (railway brakers; signallers and shunters)',
                     'Train dispatcher (railway yard)',
                     'Moped delivery driver',
                     'Motorcycle delivery driver',
                     'Delivery car driver',
                     'Delivery van driver',
                     'Passenger car driver',
                     'Mobility service bus driver',
                     'Mobility service driver',
                     'Breakdown-lorry driver',
                     'Car pilot',
                     'Distribution van driver',
                     'International driver',
                     'International driver (lorry)',
                     'Longhaul driver',
                     'Lorry driver',
                     'Mobile library driver',
                     'Refuse lorry driver',
                     'Sludge lorry driver',
                     'Tank lorry driver',
                     'Timber lorry driver',
                     'Trailer tractor driver',
                     'Combine harvester driver',
                     'Debarker operator (forestry)',
                     'Forest machine operator',
                     'Forest tractor driver',
                     'Machine operator (agriculture)',
                     'Process operator (forestry)',
                     'Asphalt paver driver',
                     'Concrete pump operator',
                     'Crawler tractor driver',
                     'De-icer',
                     'De-icing machine driver',
                     'Ground work machine driver',
                     'Ice-making machine driver',
                     'Loader driver',
                     'Loader driver (mine)',
                     'Ordinary seaman',
                     'Pump operator',
                     'Seaman',
                     "Ship's purser",
                     'Telpher operator',
                     'Tower crane operator',
                     'Fork-lift truck driver',
                     'Stacker (timber yard)',
                     'Tractor driver (industry)',
                     'Able seaman',
                     'Boatswain',
                     'Deck hand',
                     'Deck hand apprentice',
                     'Mobile crane operator',
                     'Overhead crane operator',
                     'Portal crane operator',
                     'Ropeway operator',
                     'Piling machine operator',
                     'Piste machine operator',
                     'Piste maker',
                     'Road grader driver',
                     'Road-roller driver',
                     'Roadsweeper operator',
                     'Wheel loader driver',
                     'Bridge crane operator',
                     'Building crane operator',
                     'Crane operator',
                     'Floating crane operator',
                     ]

# %%
filter_careers_83 = [i for i in filter_careers_83 if i not in items_to_remove_83]

# %%
filter_careers_24 = list(jobs.loc[jobs.ISCO == 24].careers_in_major.values)

# %%
items_to_remove_24 = ['Adviser (private economy)',
                     'PR assistant',
                     'PR consultant',
                     'Product manager (marketing)',
                     'Project manager (advertising)',
                     'Trailer producer',
                     'Information assistant',
                     'Information consultant',
                     'Information expert',
                     'Information provider',
                     'Advertising assistant (Business professionals)',
                     'Lettering artist (advertising and publicity)',
                     'Staff development officer',
                     'Staff education officer',
                     'Office efficiency adviser',
                     'School careers assistant',
                     'Staff assistant',
                     'Study adviser (personnel and careers professionals)',
                     'Business activity adviser',
                     'Examiner (audit)',
                     'Press agent',
                     'Press secretary',
                     'Food adviser',
                     'Ideas seller',
                     'Sales engineer',
                     'Technical seller',
                     'Market analyst',
                     'Market communicator',
                     'Market consultant',
                     'Market coordinator',
                     'Staff expert',
                     'Staff representative',
                     'Staff training consultant',
                     'Staff training manager',
                     'Staff training planner',
                     'Administrative developer',
                     'Business administration investigator',
                     'Business controller',
                     'Chief auditor',
                     'Corporate controller',
                     'Financial controller',
                     'Internal auditor',
                     'Management accountant',
                     'Municipal auditor',
                     'Port accountant',
                     'Budget planner',
                     'Asset manager',
                     'Organisational consultant',
                     'Organisational developer',
                     'Business adviser',
                     'Business consultant',
                     'Quality manager',
                     'Study and careers adviser',
                     'Advertising adviser',
                     'Advertising consultant',
                     'Advertising editor',
                     'Advertising inspector',
                     ]

# %%
filter_careers_24 = [i for i in filter_careers_24 if i not in items_to_remove_24]

# %%
filter_careers_52 = list(jobs.loc[jobs.ISCO == 52].careers_in_major.values)

# %%
items_to_remove_52 = ['Shop manager (general managers of restaurants and hotels; general managers in wholesale and retail trade; general managers in transport; storage and communications)',
                     'Shop manager (production and operations department managers in wholesale and retail trade; production and operations department managers in restaurants and hotels; production and operations department managers in transport; storage and communications)',
                     'Salesperson (antiquities)',
                     'Salesperson (books; stationery)',
                     'Salesperson (convenience goods)',
                     'Salesperson (electronics/telecoms)',
                     'Salesperson (flowers)',
                     'Salesperson (furniture; household items)',
                     "Salesperson (grocer's)",
                     'Salesperson (groceries)',
                     'Salesperson (machinery; building materials)',
                     'Salesperson (music shop)',
                     'Salesperson (paint shop)',
                     'Salesperson (pet shop)',
                     'Salesperson (photographic items)',
                     'Salesperson (ready-made clothing)',
                     'Salesperson (retail)',
                     'Salesperson (specialised trade)',
                     'Salesperson (sports; toys)',
                     'Salesperson (supermarket)',
                     'Salesperson (textiles; shoes; leather)',
                     'Salesperson (tobacco; etc.)',
                     'Salesperson (watches; eyeglasses; goldware)',
                     'Salesperson (wholesale)',
                     'Service attendant',
                     'Caf?? assistant',
                     'Information cashier (shop)',
                     'Farming cashier',
                     'Spare parts salesperson',
                     'Spirits cashier',
                     'Car-park ticket seller',
                     'Cash desk assistant (cafeteria)',
                     'Cash desk assistant (restaurant)',
                     'Telephone canvasser',
                     'Telephone communicator',
                     'Cashier assistant',
                     'Church cashier',
                     'Cinema cashier',
                     'Hotel cashier',
                     'Office cashier',
                     'Public baths cashier',
                     'Restaurant cashier',
                     'Shop cashier',
                     'Theatre cashier',
                     'Demonstrator',
                     'Shop demonstrator',
                     'Car spare parts assistant',
                     "Shop assistant (butcher's)",
                     'Shop assistant (convenience goods)',
                     'Shop attendant',
                     'Sales assistant',
                     'Sales clerk',
                     'Customer service assistant',
                     'Filling station assistant',
                     'Cash office worker',
                     'Ticket seller',
                     'Union treasurer', 
                     ]

# %%
filter_careers_52 = [i for i in filter_careers_52 if i not in items_to_remove_52]

# %%
filter_careers = {'21': [filter_careers_21], 
                  '33': [filter_careers_33], 
                  '23': [filter_careers_23], 
                  '32': [filter_careers_32], 
                  '31': [filter_careers_31], 
                  '22': [filter_careers_22], 
                  '61': [filter_careers_61], 
                  '83': [filter_careers_83], 
                  '24': [filter_careers_24], 
                  '52': [filter_careers_52], 
                  '35': [filter_careers_35], 
                  '42': [filter_careers_42], 
                  '25': [filter_careers_25], 
                  '54': [filter_careers_54], 
                  '12': [filter_careers_12], 
                  '53': [filter_careers_53], 
                  '91': [filter_careers_91]}

# %%
jobs_filtered = pd.DataFrame.from_dict(filter_careers, orient = 'index', columns = ['careers_in_major']).reset_index()
jobs_filtered = jobs_filtered.rename({'index':'major_ISCO'}, axis = 1)

# %%
jobs_filtered = jobs_filtered.explode('careers_in_major')

# %%
jobs_filtered = jobs_filtered.drop_duplicates().dropna()

# %%
jobs_filtered.careers_in_major = jobs_filtered.careers_in_major.apply(lambda x: x.lower())
jobs_filtered.careers_in_major = jobs_filtered.careers_in_major.apply(lambda x: x.split(" (")[0])
jobs_filtered.careers_in_major = jobs_filtered.careers_in_major.apply(lambda x: x.split(":")[0])
jobs_filtered = jobs_filtered.drop_duplicates().dropna()

# %%
jobs_filtered.rename({'major_ISCO':'ISCO', 'careers_in_major':'careers'}, axis = 1, inplace=True)
jobs_filtered['careers_scrap_format'] = jobs_filtered.careers.apply(lambda x: x.replace(" ", "%20"))
jobs_filtered
# Out:
#    ISCO             careers  careers_scrap_format
# 0    21          astronomer            astronomer
# 0    21    atomic physicist    atomic%20physicist
# 0    21  hospital physicist  hospital%20physicist
# 0    21   nuclear physicist   nuclear%20physicist
# 0    21  particle physicist  particle%20physicist
# ..  ...                 ...                   ...
# 16   91             cleaner               cleaner
# 16   91              ironer                ironer
# 16   91              washer                washer
# 16   91   washing assistant   washing%20assistant
# 16   91      window cleaner      window%20cleaner
#
# [672 rows x 3 columns]

# %%
jobs_filtered.to_csv('jobs_filtered.csv')
