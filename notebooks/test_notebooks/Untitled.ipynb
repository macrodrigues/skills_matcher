# %%
import pandas as pd

# %%
df_auto = pd.read_csv('data_only_auto.csv')
df_manual = pd.read_csv('data_only_manual.csv')

# %%
df_auto = df_auto.rename(columns = {'Unnamed: 0': 'index'})
df_manual = df_manual.rename(columns = {'Unnamed: 0': 'index'})

# %%
df_manual
# Out:
#       index  Unnamed: 0.1  Unnamed: 0.1.1  ISCO  \
# 0         0             0               0    21
# 1         1             1               1    21
# 2         2             2               2    21
# 3         3             3               3    21
# 4         4             4               4    21
# ...     ...           ...             ...   ...
# 4407   1907          4407            4407    91
# 4408   1908          4408            4408    91
# 4409   1909          4409            4409    91
# 4410   1910          4410            4410    91
# 4411   1911          4411            4411    91
#
#                                   major_job        job  \
# 0     SCIENCE AND ENGINEERING PROFESSIONALS  physicist
# 1     SCIENCE AND ENGINEERING PROFESSIONALS  physicist
# 2     SCIENCE AND ENGINEERING PROFESSIONALS  physicist
# 3     SCIENCE AND ENGINEERING PROFESSIONALS  physicist
# 4     SCIENCE AND ENGINEERING PROFESSIONALS  physicist
# ...                                     ...        ...
# 4407                   CLEANERS AND HELPERS     washer
# 4408                   CLEANERS AND HELPERS     washer
# 4409                   CLEANERS AND HELPERS     washer
# 4410                   CLEANERS AND HELPERS     washer
# 4411                   CLEANERS AND HELPERS     washer
#
#                                                position  \
# 0                         Accelerator Physicist id54315
# 1     Applied Physicist (Computing) (EP-LBC-2021-125...
# 2     Accelerator Physicist (BE-ABP-LNO-2021-122-LD)...
# 3                             Medical Devices Physicist
# 4                                    Fluidics Physicist
# ...                                                 ...
# 4407                                Dishwasher employee
# 4408  Detail Technician/Fleet Washer/Truck Washer/Au...
# 4409  Detail Technician/Fleet Washer/Truck Washer/Au...
# 4410  Detail Technician/Fleet Washer/Truck Washer/Au...
# 4411  Horeca Medewerker Afwas/Stewarding / Hospitali...
#
#                       location  \
# 0         Villigen PSI, Aargau
# 1                       Geneva
# 2                       Geneva
# 3       Newton, Cambridgeshire
# 4                    Cambridge
# ...                        ...
# 4407  Amsterdam, Noord-Holland
# 4408                  Michigan
# 4409     Warszawa, Mazowieckie
# 4410                  Michigan
# 4411  Eindhoven, Noord-Brabant
#
#                                             description  \
# 0     [' You have an academic degree in physics or e...
# 1     [' Be in charge of the development of applicat...
# 2     [' Contribute to the maintenance and developme...
# 3     [' Agency: Newton Colmore Consulting Reference...
# 4     [' Agency: Newton Colmore Consulting Reference...
# ...                                                 ...
# 4407  [' Eye for detail and through! You have a real...
# 4408  [' Paid Training Direct Care (health) Paid Vac...
# 4409  [' Paid Training Direct Care (health) Paid Vac...
# 4410  [' Paid Training Direct Care (health) Paid Vac...
# 4411  [' Enthousiast en energiek Eerlijk Flexibel in...
#
#                                   entities_manual_label
# 0     [{'entity': physics, 'label': 'KNOWLEDGE'}, {'...
# 1     [{'entity': Python, 'label': 'SKILL'}, {'entit...
# 2     [{'entity': rel="nofollow">http://madx.web.cer...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4407                                                 []
# 4408  [{'entity': driver's license, 'label': 'KNOWLE...
# 4409  [{'entity': driver's license, 'label': 'KNOWLE...
# 4410  [{'entity': driver's license, 'label': 'KNOWLE...
# 4411                                                 []
#
# [4412 rows x 10 columns]

# %%
data_final = df_auto.merge(df_manual[['index', 'entities_manual_label']], on = 'index', how = 'inner')

# %%
data_final
# Out:
#       index  ISCO                              major_job                 job  \
# 0         0    21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 1         0    21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 2         0    21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 3         1    21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 4         1    21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# ...     ...   ...                                    ...                 ...
# 4407   1907    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 4408   1908    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 4409   1909    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 4410   1910    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 4411   1911    22                   HEALTH PROFESSIONALS  veterinary surgeon
#
#                                                position  \
# 0                         Accelerator Physicist id54315
# 1                         Accelerator Physicist id54315
# 2                         Accelerator Physicist id54315
# 3     Applied Physicist (Computing) (EP-LBC-2021-125...
# 4     Applied Physicist (Computing) (EP-LBC-2021-125...
# ...                                                 ...
# 4407                           Locum Veterinary Surgeon
# 4408                                 Veterinary Surgeon
# 4409                       Permanent Veterinary Surgeon
# 4410                           Locum Veterinary Surgeon
# 4411                                 Veterinary Surgeon
#
#                             location  \
# 0               Villigen PSI, Aargau
# 1               Villigen PSI, Aargau
# 2               Villigen PSI, Aargau
# 3                             Geneva
# 4                             Geneva
# ...                              ...
# 4407       Isle of Dogs, East London
# 4408  Middlesbrough, North Yorkshire
# 4409      Harrogate, North Yorkshire
# 4410                       Lancaster
# 4411       Beckenham, Greater London
#
#                                             description entities_auto_label  \
# 0     [' You have an academic degree in physics or e...                  ()
# 1     [' You have an academic degree in physics or e...                  ()
# 2     [' You have an academic degree in physics or e...                  ()
# 3     [' Be in charge of the development of applicat...    (Python, Python)
# 4     [' Be in charge of the development of applicat...    (Python, Python)
# ...                                                 ...                 ...
# 4407  [' Type: Small Animal Start Date: 20th Decembe...                  ()
# 4408  [' Allocated CPD funding of 37.5 hours ', ' 5 ...                  ()
# 4409  [" Experienced required: New Graduate level to...                  ()
# 4410  [' Type: Small Animal Start Date: 6th January ...                  ()
# 4411  [' Allocated CPD funding of £1000 & 37.5 hours...                  ()
#
#                                   entities_manual_label
# 0     [{'entity': physics, 'label': 'KNOWLEDGE'}, {'...
# 1     [{'entity': RICS, 'label': 'SKILL'}, {'entity'...
# 2     [{'entity': CIS, 'label': 'SKILL'}, {'entity':...
# 3     [{'entity': Python, 'label': 'SKILL'}, {'entit...
# 4                                                    []
# ...                                                 ...
# 4407                                                 []
# 4408  [{'entity': driver's license, 'label': 'KNOWLE...
# 4409  [{'entity': driver's license, 'label': 'KNOWLE...
# 4410  [{'entity': driver's license, 'label': 'KNOWLE...
# 4411                                                 []
#
# [4412 rows x 9 columns]

# %%
for index, row in data_final.iterrows():
    if row.entities_auto_label == '()' and row.entities_manual_label == '[]':
        data_final.drop(index, inplace=True)

# %%
data_final = data_final.reset_index().drop(['level_0', 'index'], axis = 1)

# %%
data_final.to_csv('data_final_raw.csv')

# %%
data_final
# Out:
#       ISCO                              major_job                 job  \
# 0       21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 1       21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 2       21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 3       21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# 4       21  SCIENCE AND ENGINEERING PROFESSIONALS           physicist
# ...    ...                                    ...                 ...
# 3502    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 3503    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 3504    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 3505    22                   HEALTH PROFESSIONALS  veterinary surgeon
# 3506    22                   HEALTH PROFESSIONALS  veterinary surgeon
#
#                                                position  \
# 0                         Accelerator Physicist id54315
# 1                         Accelerator Physicist id54315
# 2                         Accelerator Physicist id54315
# 3     Applied Physicist (Computing) (EP-LBC-2021-125...
# 4     Applied Physicist (Computing) (EP-LBC-2021-125...
# ...                                                 ...
# 3502                                 Veterinary Surgeon
# 3503                       Permanent Veterinary Surgeon
# 3504                                 Veterinary Surgeon
# 3505                       Permanent Veterinary Surgeon
# 3506                           Locum Veterinary Surgeon
#
#                             location  \
# 0               Villigen PSI, Aargau
# 1               Villigen PSI, Aargau
# 2               Villigen PSI, Aargau
# 3                             Geneva
# 4                             Geneva
# ...                              ...
# 3502                         England
# 3503  Cricklewood, North West London
# 3504  Middlesbrough, North Yorkshire
# 3505      Harrogate, North Yorkshire
# 3506                       Lancaster
#
#                                             description entities_auto_label  \
# 0     [' You have an academic degree in physics or e...                  ()
# 1     [' You have an academic degree in physics or e...                  ()
# 2     [' You have an academic degree in physics or e...                  ()
# 3     [' Be in charge of the development of applicat...    (Python, Python)
# 4     [' Be in charge of the development of applicat...    (Python, Python)
# ...                                                 ...                 ...
# 3502  [' Allocated CPD funding of 37.5 hours Excelle...                  ()
# 3503  [' Type: Small Animal Hours: Monday - Friday 4...                  ()
# 3504  [' Allocated CPD funding of 37.5 hours ', ' 5 ...                  ()
# 3505  [" Experienced required: New Graduate level to...                  ()
# 3506  [' Type: Small Animal Start Date: 6th January ...                  ()
#
#                                   entities_manual_label
# 0     [{'entity': physics, 'label': 'KNOWLEDGE'}, {'...
# 1     [{'entity': RICS, 'label': 'SKILL'}, {'entity'...
# 2     [{'entity': CIS, 'label': 'SKILL'}, {'entity':...
# 3     [{'entity': Python, 'label': 'SKILL'}, {'entit...
# 4                                                    []
# ...                                                 ...
# 3502  [{'entity': driving licence, 'label': 'KNOWLED...
# 3503  [{'entity': driver's license, 'label': 'KNOWLE...
# 3504  [{'entity': driver's license, 'label': 'KNOWLE...
# 3505  [{'entity': driver's license, 'label': 'KNOWLE...
# 3506  [{'entity': driver's license, 'label': 'KNOWLE...
#
# [3507 rows x 8 columns]
